# %% [markdown]
# # **Latar Belakang**

# %% [markdown]
# Dalam era transportasi yang terus berkembang, peningkatan mobilitas penduduk kota dan permintaan layanan transportasi yang lebih efisien telah mendorong pertumbuhan industri transportasi berbasis aplikasi. Salah satu layanan yang populer di New-York adalah TLC atau Taxi and Limousine Commission, yang telah mengalami pertumbuhan pesat dalam beberapa tahun terakhir.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Industri TLC ini memiliki tantangan penting dalam mengoptimalkan penggunaan armada taksi mereka. Dalam konteks ini, penggunaan optimal merujuk pada pengaturan yang cerdas dan efisien dari armada taksi, dengan tujuan mengurangi waktu tunggu pelanggan, meningkatkan efisiensi operasional, dan pada akhirnya, meningkatkan pengalaman pelanggan. Hal yang bisa dipertimbangkan :
#
# - Jenis Transaksi
# - Waktu padat transaksi
# - Hari padat transaksi
# - Lokasi penjemputan dan pengantaran transaksi
# - Jarak tempuh transaksi
# - Kemacetan lalu lintas
# - Mobilisasi Armada
# - Metode Pembayaran

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# Untuk kasus ini, kita menggunakan dataset NYC TLC Trip Record tahun 2023. Berikut adalah penjelasan untuk tiap kolom databasenya
#
# - VendorID: Kode yang menunjukkan penyedia LPEP yang menyediakan rekaman.
#   - 1 = Creative Mobile Technologies, LLC.
#   - 2 = VeriFone Inc.
# - lpep_pickup_datetime: Tanggal dan waktu saat meteran diaktifkan.
# - lpep_dropoff_datetime: Tanggal dan waktu saat meteran dinon-aktifkan.
# - Store_and_fwd_flag: catatan perjalanan disimpan di memori kendaraan sebelum dikirim ke vendor, aka “store and forward,” karena kendaraan tidak memiliki koneksi ke server.
#   - Y = store and forward trip
#   - N = not a store and forward trip
# - RateCodeID: Kode tarif akhir yang berlaku pada akhir perjalanan..
#   - 1 = Standard rate
#   - 2 =JFK
#   - 3 =Newark
#   - 4 =Nassau or Westchester
#   - 5 =Negotiated fare
#   - 6 =Group ride
# - Passenger_count: Jumlah penumpang.
# - Trip_distance: Jarak dalam mil.
# - PULocationID: Zona saat meteran diaktifkan.
# - DOLocationID: Zona saat meteran dinon-aktifkan.
# - Payment_type: Kode numerik yang menandakan pembayaran yang dilakukan oleh penumpang.
#   - 1 = Credit card
#   - 2 = Cash
#   - 3 = No charge
#   - 4 = Dispute
#   - 5 = Unknown
#   - 6 = Voided trip
# - Fare_amount: Tarif waktu dan jarak dihitung dengan meteran. Ekstra Lain-lain Ekstra dan biaya tambahan. Saat ini, ini hanya mencakup
#   jam sibuk dan biaya malam
# - MTA_tax: Pajak MTA sebesar $0,50 secara otomatis berdasarkan tarif meteran yang digunakan.
# - Improvement_surcharge: Biaya tambahan perbaikan sebesar $0,30
# - Tip_amount: Tip yang diberikan penumpang untuk pembayaran credit card
# - Tolls_amount: Total biaya tol jika melewati tol.
# - Total_amount: Total biaya yang dibayarkan oleh penumpang.
# - Trip_type: Kode yang menandakan penumpang memesan melalui aplikasi atau mencari taxi secara acak di jalan.
#   - 1 = Street-hail
#   - 2 = Dispatch
# - eHail fee adalah biaya atau tambahan biaya yang dikenakan kepada pengguna layanan taksi atau transportasi berbasis aplikasi ketika mereka memesan taksi melalui platform elektronik atau aplikasi.
# - Congestion surcharge adalah biaya tambahan yang dikenakan kepada pengguna layanan transportasi, seperti taksi atau layanan berbasis aplikasi, ketika mereka menggunakan layanan tersebut dalam kondisi lalu lintas yang padat atau di daerah-daerah dengan kemacetan tinggi.

# %% [markdown]
# # **Data Preprocessing**

# %%
# import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
# load dataset
pd.set_option('display.max_columns', None)
df = pd.read_csv('NYC TLC Trip Record.csv')
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1             2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2             2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3             1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4             1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
# ...         ...                  ...                   ...                ...
# 68206         2  2023-01-31 22:29:00   2023-01-31 22:42:00                NaN
# 68207         2  2023-01-31 22:40:00   2023-01-31 22:48:00                NaN
# 68208         2  2023-01-31 23:46:00   2023-02-01 00:02:00                NaN
# 68209         2  2023-01-31 23:01:00   2023-01-31 23:19:00                NaN
# 68210         2  2023-01-31 23:51:00   2023-02-01 00:07:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0           166           143              1.0           2.58
# 1             1.0            24            43              1.0           1.81
# 2             1.0           223           179              1.0           0.00
# 3             1.0            41           238              1.0           1.30
# 4             1.0            41            74              1.0           1.10
# ...           ...           ...           ...              ...            ...
# 68206         NaN            49            62              NaN        4070.82
# 68207         NaN            10           205              NaN           2.14
# 68208         NaN            66            37              NaN           3.44
# 68209         NaN           225           189              NaN           3.03
# 68210         NaN           256           140              NaN           5.82
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0            14.90    1.0      0.5        4.03           0.0        NaN
# 1            10.70    1.0      0.5        2.64           0.0        NaN
# 2             7.20    1.0      0.5        1.94           0.0        NaN
# 3             6.50    0.5      1.5        1.70           0.0        NaN
# 4             6.00    0.5      1.5        0.00           0.0        NaN
# ...            ...    ...      ...         ...           ...        ...
# 68206        15.70    0.0      0.0        0.00           0.0        NaN
# 68207         4.41    0.0      0.0        0.00           0.0        NaN
# 68208        16.53    0.0      0.0        3.51           0.0        NaN
# 68209        14.98    0.0      0.0        3.20           0.0        NaN
# 68210        23.65    0.0      0.0        2.00           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        1.0         24.18           1.0        1.0
# 1                        1.0         15.84           1.0        1.0
# 2                        1.0         11.64           1.0        1.0
# 3                        1.0         10.20           1.0        1.0
# 4                        1.0          8.00           1.0        1.0
# ...                      ...           ...           ...        ...
# 68206                    1.0         16.70           NaN        NaN
# 68207                    1.0          5.41           NaN        NaN
# 68208                    1.0         21.04           NaN        NaN
# 68209                    1.0         19.18           NaN        NaN
# 68210                    1.0         29.40           NaN        NaN
#
#        congestion_surcharge
# 0                      2.75
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 68206                   NaN
# 68207                   NaN
# 68208                   NaN
# 68209                   NaN
# 68210                   NaN
#
# [68211 rows x 20 columns]

# %%
# Cek info tentang masing masing kolom di dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  object
#  2   lpep_dropoff_datetime  68211 non-null  object
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  68211 non-null  float64
#  16  total_amount           68211 non-null  float64
#  17  payment_type           63887 non-null  float64
#  18  trip_type              63877 non-null  float64
#  19  congestion_surcharge   63887 non-null  float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 10.4+ MB

# %% [markdown]
# Data awal terdiri dari 68211 baris dan 20 kolom.
#
# Tetapi, data tidak semata-mata bisa digunakan. Perlu ditinjau beberapa hal sebelum data benar-benar digunakan untuk analisis seperti :
#
# - Menyesuaikan tipe kolom
# - Handling Data
#   - Missing Values
#   - Duplikat
#   - Anomali

# %% [markdown]
# Berdasarkan tipe masing-masing kolom, ada yang perlu diubah yaitu lpep_pickup_datetime dan lpep_dropoff_datetime dari object menjadi datetime

# %%
df['lpep_pickup_datetime'] = df['lpep_pickup_datetime'].astype('datetime64[s]')
df['lpep_dropoff_datetime'] = df['lpep_dropoff_datetime'].astype('datetime64[s]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  68211 non-null  datetime64[s]
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  68211 non-null  float64
#  16  total_amount           68211 non-null  float64
#  17  payment_type           63887 non-null  float64
#  18  trip_type              63877 non-null  float64
#  19  congestion_surcharge   63887 non-null  float64
# dtypes: datetime64[s](2), float64(14), int64(3), object(1)
# memory usage: 10.4+ MB

# %% [markdown]
# Sebelum Handling Data, saya akan melakukan penambahan beberapa kolom untuk mempermudah analisis seperti waktu tempuh, lokasi zona awal dan akhir.
#
# Data lokasi dan zona new york saya ambil dataset berikut https://d37ci6vzurychx.cloudfront.net/misc/taxi+_zone_lookup.csv

# %%
# menambahkan kolom waktu tempuh
df['trip_time'] = (df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']).dt.total_seconds()

# menambahkan kolom hari
df['day'] = df['lpep_pickup_datetime'].dt.strftime('%A')

def map_time_of_day(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 21:
        return 'Evening'
    elif 21 <= hour < 24:
        return 'Night'
    else:
        return 'Midnight'

# Apply the mapping function to the 'timestamp' column
df['time_of_day'] = df['lpep_pickup_datetime'].apply(lambda x: map_time_of_day(x.hour))


# menambahkan lokasi awal dan akhir
df_zone = pd.read_csv('taxi+_zone_lookup.csv')

# memasukkan kolom lokasi pickup
df = pd.merge(df,df_zone, left_on = 'PULocationID',right_on = 'LocationID')
df = df.rename(columns={"Borough":"pickup_borough","Zone":"pickup_zone","service_zone":"pickup_service_zone"})

# memasukkan kolom lokasi dropoff
df = pd.merge(df,df_zone, left_on = 'DOLocationID',right_on = 'LocationID')
df = df.rename(columns={"Borough":"dropoff_borough","Zone":"dropoff_zone","service_zone":"dropoff_service_zone"})
df = df.drop(columns=['LocationID_x','LocationID_y','pickup_service_zone','dropoff_service_zone'])

df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-02 18:56:58   2023-01-02 19:14:50                  N
# 2         2  2023-01-03 15:28:11   2023-01-03 15:47:47                  N
# 3         2  2023-01-03 17:37:14   2023-01-03 17:51:35                  N
# 4         1  2023-01-03 19:03:53   2023-01-03 19:17:50                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
# 1         1.0           166           143              1.0           3.16
# 2         1.0           166           143              1.0           2.55
# 3         1.0           166           143              1.0           1.96
# 4         1.0           166           143              2.0           2.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         14.9   1.00      0.5        4.03           0.0        NaN
# 1         19.8   0.00      0.5        0.00           0.0        NaN
# 2         19.1   0.00      0.5        4.67           0.0        NaN
# 3         15.6   2.50      0.5        0.00           0.0        NaN
# 4         13.5   5.25      1.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         24.05           2.0        1.0
# 2                    1.0         28.02           1.0        1.0
# 3                    1.0         22.35           2.0        1.0
# 4                    1.0         20.25           2.0        1.0
#
#    congestion_surcharge  trip_time      day time_of_day pickup_borough  \
# 0                  2.75      661.0   Sunday    Midnight      Manhattan
# 1                  2.75     1072.0   Monday     Evening      Manhattan
# 2                  2.75     1176.0  Tuesday   Afternoon      Manhattan
# 3                  2.75      861.0  Tuesday   Afternoon      Manhattan
# 4                  2.75      837.0  Tuesday     Evening      Manhattan
#
#            pickup_zone dropoff_borough         dropoff_zone
# 0  Morningside Heights       Manhattan  Lincoln Square West
# 1  Morningside Heights       Manhattan  Lincoln Square West
# 2  Morningside Heights       Manhattan  Lincoln Square West
# 3  Morningside Heights       Manhattan  Lincoln Square West
# 4  Morningside Heights       Manhattan  Lincoln Square West

# %% [markdown]
# ## **Handling Data**

# %% [markdown]
# ### **Handling Missing Values**

# %%
# cek missing values
df.isna().sum()
# Out:
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag        4324
# RatecodeID                4324
# PULocationID                 0
# DOLocationID                 0
# passenger_count           4324
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                68211
# improvement_surcharge        0
# total_amount                 0
# payment_type              4324
# trip_type                 4334
# congestion_surcharge      4324
# trip_time                    0
# day                          0
# time_of_day                  0
# pickup_borough               0
# pickup_zone                 66
# dropoff_borough              0
# dropoff_zone               242
# dtype: int64

# %% [markdown]
# Karena semua data pada ehail_fee bernilai NaN maka kolom ini dapat dihapus karena tidak digunakan juga dalam analisis kali ini

# %%
df = df.drop(columns='ehail_fee')
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# store_and_fwd_flag       4324
# RatecodeID               4324
# PULocationID                0
# DOLocationID                0
# passenger_count          4324
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type             4324
# trip_type                4334
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom store_and_fwd_flag sesuai yang sudah dijelaskan pada data understanding. Pada kasus ini, kita tidak membutuhkannya analisis. Jadi bisa dihapus kolomnya ataupun diisi dengan nilai modus. Kali ini saya akan coba menghapus saja kolomnya

# %%
df = df.drop(columns='store_and_fwd_flag')
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# RatecodeID               4324
# PULocationID                0
# DOLocationID                0
# passenger_count          4324
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type             4324
# trip_type                4334
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom RatecodeID merupakan angka yang menunjukkan jenis harga yang diberlakukan. Untuk handle missing values kolom ini, bisa dilakukan dengan melihat lokasi pickup dan dropoff.
#
# - Untuk yang pickup atau dropoffnya berada di JFK Airport, maka akan diganti RatecodeIDnya menjadi 2
# - Untuk yang pickup atau dropoffnya berada di Newark Airport, maka akan diganti RatecodeIDnya menjadi 3
# - Untuk missing values sisanya, akan dianggap standard rate atau RatecodeIDnya 1

# %%
df.loc[((df['PULocationID'] == 132) | (df['DOLocationID'] == 132)) & (df['RatecodeID'].isna()), 'RatecodeID'] = 2
df.loc[((df['PULocationID'] == 1) | (df['DOLocationID'] == 1)) & (df['RatecodeID'].isna()), 'RatecodeID'] = 3
df['RatecodeID'] = df['RatecodeID'].fillna(1)
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# RatecodeID                  0
# PULocationID                0
# DOLocationID                0
# passenger_count          4324
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type             4324
# trip_type                4334
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom passenger_count tidak terlalu digunakan untuk analisis kali ini, jadi nilai missing values ataupun yang nilainya 0 bisa diisi dengan nilai modus

# %%
df['passenger_count'] = df['passenger_count'].replace(0,df['passenger_count'].mode().values[0])
df['passenger_count'] = df['passenger_count'].fillna(df['passenger_count'].mode().values[0])
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# RatecodeID                  0
# PULocationID                0
# DOLocationID                0
# passenger_count             0
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type             4324
# trip_type                4334
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom payment_type bisa diisi dengan nomor 6 (VOIDED TRIP) apabila tidak ada trip distance ataupun total amount. Selain itu ada beberapa kondisi lain seperti:
#
# - Apabila ada tip amount maka payment_typenya 1 (CREDIT CARD)
# - Apabila tidak ada tip tetapi total amountnya ada, bisa diganti menjadi 5 (UNKNOWN)

# %%
df.loc[(df['trip_distance'] == 0) & (df['total_amount'] == 0) & (df['payment_type'].isna()), 'payment_type'] = 6
df.loc[(df['tip_amount'] != 0) & (df['payment_type'].isna()), 'payment_type'] = 1
df['payment_type'] = df['payment_type'].fillna(5)
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# RatecodeID                  0
# PULocationID                0
# DOLocationID                0
# passenger_count             0
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type                0
# trip_type                4334
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom trip_type karena bisa kita isi dengan unknown atau kita buat kode baru yaitu 3. Karena tidak bisa dideklarasikan apakah ia street-hail atau dispatch yang dikhawatirkan akan mempengaruhi analisis.

# %%
df['trip_type'] = df['trip_type'].fillna(3)
df.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# RatecodeID                  0
# PULocationID                0
# DOLocationID                0
# passenger_count             0
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# payment_type                0
# trip_type                   0
# congestion_surcharge     4324
# trip_time                   0
# day                         0
# time_of_day                 0
# pickup_borough              0
# pickup_zone                66
# dropoff_borough             0
# dropoff_zone              242
# dtype: int64

# %% [markdown]
# Kolom congestion_surcharge merupakan biaya tambahan ketika terjadi kemacetan. Dan itu berpengaruh kepada total amount sedangkan total_amount semua nilainya sudah ada bahkan ketika nilai nilai missing values diatas tadi belum terisi. Maka dari itu kita asumsikan untuk nilai congestion_surcharge pada missing values ini diisi menjadi 0

# %%
df['congestion_surcharge'] = df['congestion_surcharge'].fillna(0)
df.isna().sum()
# Out:
# VendorID                   0
# lpep_pickup_datetime       0
# lpep_dropoff_datetime      0
# RatecodeID                 0
# PULocationID               0
# DOLocationID               0
# passenger_count            0
# trip_distance              0
# fare_amount                0
# extra                      0
# mta_tax                    0
# tip_amount                 0
# tolls_amount               0
# improvement_surcharge      0
# total_amount               0
# payment_type               0
# trip_type                  0
# congestion_surcharge       0
# trip_time                  0
# day                        0
# time_of_day                0
# pickup_borough             0
# pickup_zone               66
# dropoff_borough            0
# dropoff_zone             242
# dtype: int64

# %% [markdown]
# Setelah saya mengambil data dari https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page dan mendownload https://d37ci6vzurychx.cloudfront.net/misc/taxi+_zone_lookup.csv' untuk 2023
#
# Ada 2 ID yang memiliki nilai Unknown dan N/A untuk zonenya. Jadi data tersebut akan di drop untuk melanjutkan analisis berikutnya

# %%
df = df[(df['PULocationID'] != 264) & (df['DOLocationID'] != 264) & (df['PULocationID'] != 265) & (df['DOLocationID'] != 265)]
df.isna().sum()
# Out:
# VendorID                 0
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# payment_type             0
# trip_type                0
# congestion_surcharge     0
# trip_time                0
# day                      0
# time_of_day              0
# pickup_borough           0
# pickup_zone              0
# dropoff_borough          0
# dropoff_zone             0
# dtype: int64

# %% [markdown]
# ### **Handling Duplicate**

# %%
# cek duplicate
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tidak ada data yang duplikat

# %% [markdown]
# ### **Handling Anomaly**
#
# Ada beberapa kondisi dimana data tersebut anomali. Kita akan coba menelusurinya satu satu per kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67499 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               67499 non-null  int64
#  1   lpep_pickup_datetime   67499 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  67499 non-null  datetime64[s]
#  3   RatecodeID             67499 non-null  float64
#  4   PULocationID           67499 non-null  int64
#  5   DOLocationID           67499 non-null  int64
#  6   passenger_count        67499 non-null  float64
#  7   trip_distance          67499 non-null  float64
#  8   fare_amount            67499 non-null  float64
#  9   extra                  67499 non-null  float64
#  10  mta_tax                67499 non-null  float64
#  11  tip_amount             67499 non-null  float64
#  12  tolls_amount           67499 non-null  float64
#  13  improvement_surcharge  67499 non-null  float64
#  14  total_amount           67499 non-null  float64
#  15  payment_type           67499 non-null  float64
#  16  trip_type              67499 non-null  float64
#  17  congestion_surcharge   67499 non-null  float64
#  18  trip_time              67499 non-null  float64
#  19  day                    67499 non-null  object
#  20  time_of_day            67499 non-null  object
#  21  pickup_borough         67499 non-null  object
#  22  pickup_zone            67499 non-null  object
#  23  dropoff_borough        67499 non-null  object
#  24  dropoff_zone           67499 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 13.4+ MB

# %% [markdown]
# #### **Trip Distance**
#
# Kota new york memiliki luas 468,9 sq mil, apabila kita asumsikan new york adalah sebuah lingkaran maka keliling dari new york adalah 76,8 mil dimana saya asumsikan keliling tersebut seharusnya adalah jarak terjauh yang bisa ditempuh selama masih berada dalam kawasan new york. Maka dari itu kita buang anomali data ketika trip distancenya kurang dari 0 ataupun lebih dari 155 mil

# %%
# Cek terlebih dahulu ada berapa data yang tidak memenuhi kondisi

df[(df['trip_distance'] <= 0) | (df['trip_distance'] > 76.8)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 105           1  2023-01-12 14:05:46   2023-01-12 14:24:09         1.0
# 229           1  2023-01-12 10:39:21   2023-01-12 11:00:16         1.0
# 231           1  2023-01-23 20:34:18   2023-01-23 20:48:26         1.0
# 441           1  2023-01-03 18:42:59   2023-01-03 19:01:57         1.0
# 442           1  2023-01-25 12:29:32   2023-01-25 13:12:47         1.0
# ...         ...                  ...                   ...         ...
# 68182         1  2023-01-02 21:02:09   2023-01-02 21:28:46         1.0
# 68189         1  2023-01-08 13:11:22   2023-01-08 13:45:44         1.0
# 68195         2  2023-01-19 14:43:16   2023-01-19 14:43:27         5.0
# 68202         1  2023-01-13 19:51:38   2023-01-13 20:18:25         1.0
# 68205         1  2023-01-30 16:27:45   2023-01-30 17:24:38         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 105              41           143              1.0            0.0
# 229              75           143              1.0            0.0
# 231              75           143              1.0            0.0
# 441             231           143              1.0            0.0
# 442             165           143              1.0            0.0
# ...             ...           ...              ...            ...
# 68182           216           108              1.0            0.0
# 68189            85           108              1.0            0.0
# 68195            23            23              1.0            0.0
# 68202            14            44              1.0            0.0
# 68205           197           214              1.0            0.0
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 105          14.00    0.0      0.5         1.5          0.00
# 229          20.04    0.0      0.5         0.0          0.00
# 231          16.57    0.0      0.5         0.0          0.00
# 441          23.50    0.0      1.5         0.0          0.00
# 442          31.20    0.0      1.5         0.0          0.00
# ...            ...    ...      ...         ...           ...
# 68182        39.20    0.0      1.5         0.0          0.00
# 68189        24.50    0.0      1.5         0.0          0.00
# 68195       109.25    0.0      0.0         0.0          0.00
# 68202        40.20    0.0      1.5         0.0         25.50
# 68205        65.50    0.0      1.5         0.0          6.55
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 105                      1.0         19.50           1.0        3.0
# 229                      1.0         24.04           5.0        3.0
# 231                      1.0         20.57           5.0        3.0
# 441                      1.0         25.00           1.0        1.0
# 442                      1.0         32.70           1.0        1.0
# ...                      ...           ...           ...        ...
# 68182                    1.0         40.70           1.0        1.0
# 68189                    1.0         26.00           1.0        1.0
# 68195                    1.0        110.25           1.0        2.0
# 68202                    1.0         67.20           1.0        1.0
# 68205                    1.0         73.55           1.0        1.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 105                     0.0     1103.0   Thursday   Afternoon      Manhattan
# 229                     0.0     1255.0   Thursday     Morning      Manhattan
# 231                     0.0      848.0     Monday     Evening      Manhattan
# 441                     0.0     1138.0    Tuesday     Evening      Manhattan
# 442                     0.0     2595.0  Wednesday   Afternoon       Brooklyn
# ...                     ...        ...        ...         ...            ...
# 68182                   0.0     1597.0     Monday       Night         Queens
# 68189                   0.0     2062.0     Sunday   Afternoon       Brooklyn
# 68195                   0.0       11.0   Thursday   Afternoon  Staten Island
# 68202                   0.0     1607.0     Friday     Evening       Brooklyn
# 68205                   0.0     3413.0     Monday   Afternoon         Queens
#
#                    pickup_zone dropoff_borough              dropoff_zone
# 105             Central Harlem       Manhattan       Lincoln Square West
# 229          East Harlem South       Manhattan       Lincoln Square West
# 231          East Harlem South       Manhattan       Lincoln Square West
# 441       TriBeCa/Civic Center       Manhattan       Lincoln Square West
# 442                    Midwood       Manhattan       Lincoln Square West
# ...                        ...             ...                       ...
# 68182         South Ozone Park        Brooklyn                 Gravesend
# 68189                  Erasmus        Brooklyn                 Gravesend
# 68195  Bloomfield/Emerson Hill   Staten Island   Bloomfield/Emerson Hill
# 68202                Bay Ridge   Staten Island    Charleston/Tottenville
# 68205            Richmond Hill   Staten Island  South Beach/Dongan Hills
#
# [3029 rows x 25 columns]

# %%
# TRIP DISTANCE BERNILAI NEGATIF DAN NILAI 0

df = df[(df['trip_distance'] > 0) & (df['trip_distance'] <= 76.8)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64470 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64470 non-null  int64
#  1   lpep_pickup_datetime   64470 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64470 non-null  datetime64[s]
#  3   RatecodeID             64470 non-null  float64
#  4   PULocationID           64470 non-null  int64
#  5   DOLocationID           64470 non-null  int64
#  6   passenger_count        64470 non-null  float64
#  7   trip_distance          64470 non-null  float64
#  8   fare_amount            64470 non-null  float64
#  9   extra                  64470 non-null  float64
#  10  mta_tax                64470 non-null  float64
#  11  tip_amount             64470 non-null  float64
#  12  tolls_amount           64470 non-null  float64
#  13  improvement_surcharge  64470 non-null  float64
#  14  total_amount           64470 non-null  float64
#  15  payment_type           64470 non-null  float64
#  16  trip_type              64470 non-null  float64
#  17  congestion_surcharge   64470 non-null  float64
#  18  trip_time              64470 non-null  float64
#  19  day                    64470 non-null  object
#  20  time_of_day            64470 non-null  object
#  21  pickup_borough         64470 non-null  object
#  22  pickup_zone            64470 non-null  object
#  23  dropoff_borough        64470 non-null  object
#  24  dropoff_zone           64470 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.8+ MB

# %% [markdown]
# #### **Fare Amount**
#
# Untuk biaya taksi seharusnya tidak bisa 0

# %%
df[df['fare_amount']<0]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 1418          2  2023-01-03 11:30:37   2023-01-03 11:32:23         1.0
# 1443          2  2023-01-05 15:01:39   2023-01-05 15:02:16         1.0
# 1587          2  2023-01-18 14:41:30   2023-01-18 14:42:00         1.0
# 1783          2  2023-01-19 17:48:00   2023-01-19 17:52:00         1.0
# 1794          2  2023-01-05 10:01:30   2023-01-05 10:04:04         1.0
# ...         ...                  ...                   ...         ...
# 63252         2  2023-01-26 20:18:19   2023-01-26 20:19:08         1.0
# 63254         2  2023-01-31 22:44:16   2023-01-31 22:45:18         1.0
# 63333         2  2023-01-17 17:50:01   2023-01-17 17:50:39         1.0
# 63771         2  2023-01-09 09:38:39   2023-01-09 09:46:08         1.0
# 64799         2  2023-01-04 15:11:00   2023-01-04 15:12:00         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 1418            166           166              2.0           0.16
# 1443            166           166              1.0           0.13
# 1587            166           166              1.0           0.01
# 1783            166           166              1.0           0.38
# 1794             24           166              1.0           0.44
# ...             ...           ...              ...            ...
# 63252           256           256              2.0           0.05
# 63254           256           256              1.0           0.15
# 63333            55            55              3.0           0.05
# 63771            65            66              1.0           0.88
# 64799            25            25              1.0           0.13
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 1418         -3.70    0.0     -0.5        0.00           0.0
# 1443         -3.00    0.0     -0.5        0.00           0.0
# 1587         -3.00    0.0     -0.5        0.00           0.0
# 1783        -35.01    0.0      0.0        4.86           0.0
# 1794         -4.00    0.0     -0.5        0.00           0.0
# ...            ...    ...      ...         ...           ...
# 63252        -3.00   -1.0     -0.5        0.00           0.0
# 63254        -3.70   -1.0     -0.5        0.00           0.0
# 63333        -3.00   -2.5     -0.5        0.00           0.0
# 63771        -8.60    0.0     -0.5        0.00           0.0
# 64799       -27.96    0.0      0.0        3.00           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 1418                    -1.0         -5.20           3.0        1.0
# 1443                    -1.0         -4.50           4.0        1.0
# 1587                    -1.0         -4.50           3.0        1.0
# 1783                     1.0        -29.15           1.0        3.0
# 1794                    -0.3         -4.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 63252                   -1.0         -5.50           3.0        1.0
# 63254                   -1.0         -6.20           3.0        1.0
# 63333                   -1.0         -7.00           3.0        1.0
# 63771                   -1.0        -10.10           3.0        1.0
# 64799                    1.0        -23.96           1.0        3.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 1418                    0.0      106.0    Tuesday     Morning      Manhattan
# 1443                    0.0       37.0   Thursday   Afternoon      Manhattan
# 1587                    0.0       30.0  Wednesday   Afternoon      Manhattan
# 1783                    0.0      240.0   Thursday   Afternoon      Manhattan
# 1794                    0.0      154.0   Thursday     Morning      Manhattan
# ...                     ...        ...        ...         ...            ...
# 63252                   0.0       49.0   Thursday     Evening       Brooklyn
# 63254                   0.0       62.0    Tuesday       Night       Brooklyn
# 63333                   0.0       38.0    Tuesday   Afternoon       Brooklyn
# 63771                   0.0      449.0     Monday     Morning       Brooklyn
# 64799                   0.0       60.0  Wednesday   Afternoon       Brooklyn
#
#                        pickup_zone dropoff_borough               dropoff_zone
# 1418           Morningside Heights       Manhattan        Morningside Heights
# 1443           Morningside Heights       Manhattan        Morningside Heights
# 1587           Morningside Heights       Manhattan        Morningside Heights
# 1783           Morningside Heights       Manhattan        Morningside Heights
# 1794                  Bloomingdale       Manhattan        Morningside Heights
# ...                            ...             ...                        ...
# 63252    Williamsburg (South Side)        Brooklyn  Williamsburg (South Side)
# 63254    Williamsburg (South Side)        Brooklyn  Williamsburg (South Side)
# 63333                 Coney Island        Brooklyn               Coney Island
# 63771  Downtown Brooklyn/MetroTech        Brooklyn         DUMBO/Vinegar Hill
# 64799                  Boerum Hill        Brooklyn                Boerum Hill
#
# [104 rows x 25 columns]

# %% [markdown]
# Berdasarkan hasil diatas, dapat diasumsikan bahwa terjadi salah penginputan terhadap nilai fare_amoount begitupun untuk beberapa kolom lain seperti mta_tax, extra, dan nilai continous lainnya yang berdampak kepada nilai total_amount
#
# Kita bisa memperbaikinya dengan merubah nilai negatif menjadi nilai positif. Tetapi ada beberapa perubahan yang akan terjadi, khususnya pada nilai total_amount.
#
# Nilai total_amount tidak hanya akan berganti dari negatif ke positif, tapi akan tergenerate ulang jumlahnya dari hasil penjumlahan fare_amount dan kolom biaya lainnya.

# %%
# nilai mutlak untuk yang bernilai negatif
df['fare_amount'] = df['fare_amount'].abs()
df['extra'] = df['extra'].abs()
df['mta_tax'] = df['mta_tax'].abs()
df['improvement_surcharge'] = df['improvement_surcharge'].abs()
df['congestion_surcharge'] = df['congestion_surcharge'].abs()

# menjumlahkan ulang nilai total_amount
df['total_amount'] = df['fare_amount'] + df['extra'] + df['mta_tax'] + df['improvement_surcharge'] + df['congestion_surcharge']

# %% [markdown]
# Setelah itu kita perlu remove yang nilai total_amountnya tetap 0 ataupun fare_amountnya tetap 0

# %%
df = df[(df['total_amount'] > 0) & (df['fare_amount'] > 0)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64453 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64453 non-null  int64
#  1   lpep_pickup_datetime   64453 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64453 non-null  datetime64[s]
#  3   RatecodeID             64453 non-null  float64
#  4   PULocationID           64453 non-null  int64
#  5   DOLocationID           64453 non-null  int64
#  6   passenger_count        64453 non-null  float64
#  7   trip_distance          64453 non-null  float64
#  8   fare_amount            64453 non-null  float64
#  9   extra                  64453 non-null  float64
#  10  mta_tax                64453 non-null  float64
#  11  tip_amount             64453 non-null  float64
#  12  tolls_amount           64453 non-null  float64
#  13  improvement_surcharge  64453 non-null  float64
#  14  total_amount           64453 non-null  float64
#  15  payment_type           64453 non-null  float64
#  16  trip_type              64453 non-null  float64
#  17  congestion_surcharge   64453 non-null  float64
#  18  trip_time              64453 non-null  float64
#  19  day                    64453 non-null  object
#  20  time_of_day            64453 non-null  object
#  21  pickup_borough         64453 non-null  object
#  22  pickup_zone            64453 non-null  object
#  23  dropoff_borough        64453 non-null  object
#  24  dropoff_zone           64453 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.8+ MB

# %%
unique = []
for col in df.columns :
    if col in ['store_and_fwd_flag', 'RatecodeID','passenger_count','payment_type', 'trip_type', 'congestion_surcharge']:
        unique.append( [col,df[col].unique()])

df_unique = pd.DataFrame(columns=['Column','Unique'],
                     data=unique)
df_unique
# Out:
#                  Column                                    Unique
# 0            RatecodeID           [1.0, 5.0, 2.0, 3.0, 4.0, 99.0]
# 1       passenger_count  [1.0, 2.0, 3.0, 6.0, 4.0, 5.0, 8.0, 7.0]
# 2          payment_type                 [1.0, 2.0, 5.0, 3.0, 4.0]
# 3             trip_type                           [1.0, 3.0, 2.0]
# 4  congestion_surcharge                          [2.75, 0.0, 2.5]

# %% [markdown]
# #### **RatecodeID**
#
# Berdasarkan tabel diatas, masih ada sedikit anomali pada RatecodeID dimana sesuai data understanding, hanya ada kode untuk 1-6.
#
# Untuk itu kita bisa cek data tersebut, apabila sedikit bisa kita hapus

# %%
df[df['RatecodeID'] == 99]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 12818         1  2023-01-19 01:07:59   2023-01-19 01:17:19        99.0
# 47739         1  2023-01-02 16:39:05   2023-01-02 17:31:42        99.0
# 62145         1  2023-01-15 13:51:42   2023-01-15 14:37:38        99.0
# 63383         1  2023-01-01 19:44:13   2023-01-01 19:58:30        99.0
# 64541         1  2023-01-05 20:33:45   2023-01-05 22:46:41        99.0
# 64552         1  2023-01-15 17:52:52   2023-01-15 22:11:55        99.0
# 64554         1  2023-01-21 20:29:58   2023-01-22 02:59:25        99.0
# 65242         1  2023-01-08 11:36:41   2023-01-08 12:14:59        99.0
# 66681         1  2023-01-23 13:45:11   2023-01-23 23:36:42        99.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 12818            90            68              1.0            0.6
# 47739            73            82              1.0            3.7
# 62145           108           181              1.0            6.5
# 63383           150            55              1.0            3.3
# 64541            14           123              1.0            6.2
# 64552           150           123              1.0            1.6
# 64554           150           123              1.0            1.4
# 65242            61            77              1.0            2.7
# 66681           244           248              1.0           28.3
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 12818         15.2    0.0      1.5         0.0           0.0
# 47739         23.5    0.0      1.5         0.0           0.0
# 62145         24.2    0.0      1.5         0.0           0.0
# 63383         18.2    0.0      1.5         0.0           0.0
# 64541         28.2    0.0      1.5         0.0           0.0
# 64552         15.2    0.0      1.5         0.0           0.0
# 64554         15.2    0.0      1.5         0.0           0.0
# 65242         22.5    0.0      1.5         0.0           0.0
# 66681         50.2    0.0      1.5         0.0           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 12818                    1.0          17.7           1.0        3.0
# 47739                    1.0          26.0           1.0        3.0
# 62145                    1.0          26.7           1.0        3.0
# 63383                    1.0          20.7           1.0        3.0
# 64541                    1.0          30.7           1.0        3.0
# 64552                    1.0          17.7           1.0        3.0
# 64554                    1.0          17.7           1.0        3.0
# 65242                    1.0          25.0           1.0        3.0
# 66681                    1.0          52.7           1.0        3.0
#
#        congestion_surcharge  trip_time       day time_of_day pickup_borough  \
# 12818                   0.0      560.0  Thursday    Midnight      Manhattan
# 47739                   0.0     3157.0    Monday   Afternoon         Queens
# 62145                   0.0     2756.0    Sunday   Afternoon       Brooklyn
# 63383                   0.0      857.0    Sunday     Evening       Brooklyn
# 64541                   0.0     7976.0  Thursday     Evening       Brooklyn
# 64552                   0.0    15543.0    Sunday   Afternoon       Brooklyn
# 64554                   0.0    23367.0  Saturday     Evening       Brooklyn
# 65242                   0.0     2298.0    Sunday     Morning       Brooklyn
# 66681                   0.0    35491.0    Monday   Afternoon      Manhattan
#
#                     pickup_zone dropoff_borough  \
# 12818                  Flatiron       Manhattan
# 47739             East Flushing          Queens
# 62145                 Gravesend        Brooklyn
# 63383           Manhattan Beach        Brooklyn
# 64541                 Bay Ridge        Brooklyn
# 64552           Manhattan Beach        Brooklyn
# 64554           Manhattan Beach        Brooklyn
# 65242       Crown Heights North        Brooklyn
# 66681  Washington Heights South           Bronx
#
#                             dropoff_zone
# 12818                       East Chelsea
# 47739                           Elmhurst
# 62145                         Park Slope
# 63383                       Coney Island
# 64541                          Homecrest
# 64552                          Homecrest
# 64554                          Homecrest
# 65242  East New York/Pennsylvania Avenue
# 66681             West Farms/Bronx River

# %% [markdown]
# Hanya ada 9 data yang memiliki ratecodeID = 99 , jadi bisa kita hapus datanya

# %%
df = df[df['RatecodeID'] != 99]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64444 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64444 non-null  int64
#  1   lpep_pickup_datetime   64444 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64444 non-null  datetime64[s]
#  3   RatecodeID             64444 non-null  float64
#  4   PULocationID           64444 non-null  int64
#  5   DOLocationID           64444 non-null  int64
#  6   passenger_count        64444 non-null  float64
#  7   trip_distance          64444 non-null  float64
#  8   fare_amount            64444 non-null  float64
#  9   extra                  64444 non-null  float64
#  10  mta_tax                64444 non-null  float64
#  11  tip_amount             64444 non-null  float64
#  12  tolls_amount           64444 non-null  float64
#  13  improvement_surcharge  64444 non-null  float64
#  14  total_amount           64444 non-null  float64
#  15  payment_type           64444 non-null  float64
#  16  trip_type              64444 non-null  float64
#  17  congestion_surcharge   64444 non-null  float64
#  18  trip_time              64444 non-null  float64
#  19  day                    64444 non-null  object
#  20  time_of_day            64444 non-null  object
#  21  pickup_borough         64444 non-null  object
#  22  pickup_zone            64444 non-null  object
#  23  dropoff_borough        64444 non-null  object
#  24  dropoff_zone           64444 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.8+ MB

# %% [markdown]
# #### **Pickup Datetime**
#
# Sesuai dataset yang didapat, ini adalah trip record dari bulan Januari 2023.
#
# Maka dari itu kita perlu cek apakah ada tanggal pickup yang tidak termasuk ke Januari 2023

# %%
df[(df['lpep_pickup_datetime'].dt.month != 1) | (df['lpep_pickup_datetime'].dt.year != 2023)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 41830         2  2022-12-09 14:55:42   2022-12-09 15:33:06         1.0
# 48595         2  2022-12-09 14:10:49   2022-12-09 14:22:26         1.0
# 51550         2  2023-02-01 03:10:05   2023-02-01 03:40:35         5.0
# 67728         2  2009-01-01 20:21:27   2009-01-02 11:07:31         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 41830           260           164              1.0           5.48
# 48595             7            56              1.0           5.37
# 51550            82           198              2.0           4.58
# 67728            65           178              1.0           7.72
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 41830         25.5    0.0      0.5        0.00          6.55
# 48595         16.0    0.0      0.5        0.00          0.00
# 51550         28.0    0.0      0.0        5.66          0.00
# 67728         34.5    0.0      0.5        7.20          0.00
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 41830                    0.3         29.05           2.0        1.0
# 48595                    0.3         16.80           2.0        1.0
# 51550                    0.3         28.30           1.0        2.0
# 67728                    1.0         36.00           1.0        1.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 41830                  2.75     2244.0     Friday   Afternoon         Queens
# 48595                  0.00      697.0     Friday   Afternoon         Queens
# 51550                  0.00     1830.0  Wednesday    Midnight         Queens
# 67728                  0.00    53164.0   Thursday     Evening       Brooklyn
#
#                        pickup_zone dropoff_borough         dropoff_zone
# 41830                     Woodside       Manhattan        Midtown South
# 48595                      Astoria          Queens               Corona
# 51550                     Elmhurst          Queens            Ridgewood
# 67728  Downtown Brooklyn/MetroTech        Brooklyn  Ocean Parkway South

# %% [markdown]
# Ada 4 data yang tidak termasuk Januari 2023. Jadi kita bisa hapus datanya untuk mempermudah proses analisis

# %%
df = df[(df['lpep_pickup_datetime'].dt.month == 1) & (df['lpep_pickup_datetime'].dt.year == 2023)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64440 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64440 non-null  int64
#  1   lpep_pickup_datetime   64440 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64440 non-null  datetime64[s]
#  3   RatecodeID             64440 non-null  float64
#  4   PULocationID           64440 non-null  int64
#  5   DOLocationID           64440 non-null  int64
#  6   passenger_count        64440 non-null  float64
#  7   trip_distance          64440 non-null  float64
#  8   fare_amount            64440 non-null  float64
#  9   extra                  64440 non-null  float64
#  10  mta_tax                64440 non-null  float64
#  11  tip_amount             64440 non-null  float64
#  12  tolls_amount           64440 non-null  float64
#  13  improvement_surcharge  64440 non-null  float64
#  14  total_amount           64440 non-null  float64
#  15  payment_type           64440 non-null  float64
#  16  trip_type              64440 non-null  float64
#  17  congestion_surcharge   64440 non-null  float64
#  18  trip_time              64440 non-null  float64
#  19  day                    64440 non-null  object
#  20  time_of_day            64440 non-null  object
#  21  pickup_borough         64440 non-null  object
#  22  pickup_zone            64440 non-null  object
#  23  dropoff_borough        64440 non-null  object
#  24  dropoff_zone           64440 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.8+ MB

# %% [markdown]
# ### **Dropoff Time**
#
# Pada saat saya mengecek datanya secara manual, ada beberapa data yang janggal di bagian dropoff time ini. Berikut datanya akan saya tampilkan:

# %%
df[(df['lpep_dropoff_datetime'].dt.hour == 0) & (df['lpep_dropoff_datetime'].dt.minute == 0) & (df['lpep_dropoff_datetime'].dt.second == 0)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 580           2  2023-01-26 23:38:00            2023-01-27         1.0
# 595           2  2023-01-08 03:14:21            2023-01-09         1.0
# 695           2  2023-01-23 17:26:40            2023-01-24         1.0
# 1370          2  2023-01-26 12:45:43            2023-01-27         1.0
# 4801          2  2023-01-18 14:36:04            2023-01-19         1.0
# ...         ...                  ...                   ...         ...
# 66065         2  2023-01-23 16:48:51            2023-01-24         1.0
# 67105         2  2023-01-11 21:28:35            2023-01-12         1.0
# 67802         2  2023-01-04 06:51:45            2023-01-05         1.0
# 67950         2  2023-01-16 03:13:50            2023-01-17         1.0
# 68088         2  2023-01-31 15:21:47            2023-02-01         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 580             223           244              1.0           6.24
# 595              41           244              1.0           2.51
# 695              75           244              1.0           4.73
# 1370            200           244              1.0           4.90
# 4801             75            42              1.0           2.14
# ...             ...           ...              ...            ...
# 66065            95           121              1.0           2.67
# 67105           134           197              1.0           1.63
# 67802            95            86              1.0          12.22
# 67950           129            16              2.0           9.30
# 68088            92            64              2.0           9.15
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 580          23.66    0.0      0.0        0.00          6.55
# 595          15.60    1.0      0.5        0.00          0.00
# 695          23.30    2.5      0.5        0.00          0.00
# 1370         21.90    0.0      0.5        0.00          3.00
# 4801         11.50    0.0      0.5        0.00          0.00
# ...            ...    ...      ...         ...           ...
# 66065        14.90    2.5      0.5        0.00          0.00
# 67105        10.70    1.0      0.5        0.00          0.00
# 67802        56.20    0.0      0.5        0.00          0.00
# 67950        40.10    1.0      0.5        0.00          0.00
# 68088        39.40    0.0      0.5        4.09          0.00
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 580                      1.0         24.66           5.0        3.0
# 595                      0.3         17.40           1.0        1.0
# 695                      1.0         27.30           1.0        1.0
# 1370                     1.0         23.40           2.0        1.0
# 4801                     0.3         12.30           2.0        1.0
# ...                      ...           ...           ...        ...
# 66065                    1.0         18.90           2.0        1.0
# 67105                    1.0         13.20           1.0        1.0
# 67802                    1.0         57.70           2.0        1.0
# 67950                    1.0         42.60           2.0        1.0
# 68088                    1.0         40.90           1.0        1.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 580                     0.0     1320.0   Thursday       Night         Queens
# 595                     0.0    74739.0     Sunday    Midnight      Manhattan
# 695                     0.0    23600.0     Monday   Afternoon      Manhattan
# 1370                    0.0    40457.0   Thursday   Afternoon          Bronx
# 4801                    0.0    33836.0  Wednesday   Afternoon      Manhattan
# ...                     ...        ...        ...         ...            ...
# 66065                   0.0    25869.0     Monday   Afternoon         Queens
# 67105                   0.0     9085.0  Wednesday       Night         Queens
# 67802                   0.0    61695.0  Wednesday     Morning         Queens
# 67950                   0.0    74770.0     Monday    Midnight         Queens
# 68088                   0.0    31093.0    Tuesday   Afternoon         Queens
#
#                                pickup_zone dropoff_borough  \
# 580                               Steinway       Manhattan
# 595                         Central Harlem       Manhattan
# 695                      East Harlem South       Manhattan
# 1370   Riverdale/North Riverdale/Fieldston       Manhattan
# 4801                     East Harlem South       Manhattan
# ...                                    ...             ...
# 66065                         Forest Hills          Queens
# 67105                          Kew Gardens          Queens
# 67802                         Forest Hills          Queens
# 67950                      Jackson Heights          Queens
# 68088                             Flushing          Queens
#
#                    dropoff_zone
# 580    Washington Heights South
# 595    Washington Heights South
# 695    Washington Heights South
# 1370   Washington Heights South
# 4801       Central Harlem North
# ...                         ...
# 66065         Hillcrest/Pomonok
# 67105             Richmond Hill
# 67802              Far Rockaway
# 67950                   Bayside
# 68088                Douglaston
#
# [77 rows x 25 columns]

# %% [markdown]
# Data diatas merupakan data dimana dropoff timenya adalah tepat 12 malam. Dari 19 data tesebut, ada kejanggalan dimana dropoff timenya tepat pukul 12 malam. Sedangkan untuk beberapa data diatas, pickup timenya sudah ada yang dari jam 7 malam dan juga jaraknya yang hanya dibawah 12 mil saja. Sedangkan nilai diatas juga memiliki nilai congestion_surchargenya 0 yang menandakan tidak dalam kondisi macet.
#
# Jadi beberapa data diatas akan saya anggap anomali karena kesalahan sistem dalam menginput data dropoff time.
#
# Saya akan membuang data dimana yang pickup timenya dibawah jam 11 malam dan juga jaraknya dibawah 12 mil

# %%
df = df[~((df['lpep_dropoff_datetime'].dt.hour == 0) & (df['lpep_dropoff_datetime'].dt.minute == 0) & (df['lpep_dropoff_datetime'].dt.second == 0) & (df['lpep_pickup_datetime'].dt.hour != 23) & (df['trip_distance']<12))]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64371 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64371 non-null  int64
#  1   lpep_pickup_datetime   64371 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64371 non-null  datetime64[s]
#  3   RatecodeID             64371 non-null  float64
#  4   PULocationID           64371 non-null  int64
#  5   DOLocationID           64371 non-null  int64
#  6   passenger_count        64371 non-null  float64
#  7   trip_distance          64371 non-null  float64
#  8   fare_amount            64371 non-null  float64
#  9   extra                  64371 non-null  float64
#  10  mta_tax                64371 non-null  float64
#  11  tip_amount             64371 non-null  float64
#  12  tolls_amount           64371 non-null  float64
#  13  improvement_surcharge  64371 non-null  float64
#  14  total_amount           64371 non-null  float64
#  15  payment_type           64371 non-null  float64
#  16  trip_type              64371 non-null  float64
#  17  congestion_surcharge   64371 non-null  float64
#  18  trip_time              64371 non-null  float64
#  19  day                    64371 non-null  object
#  20  time_of_day            64371 non-null  object
#  21  pickup_borough         64371 non-null  object
#  22  pickup_zone            64371 non-null  object
#  23  dropoff_borough        64371 non-null  object
#  24  dropoff_zone           64371 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.8+ MB

# %% [markdown]
# #### **Trip Time**
#
# Kolom selanjut yang perlu dicek adalah trip_time, trip_time tidak mungkin bernilai negatif.
#
# Apabila ada nilai negatif, kita bisa lihat ada berapa dan jika sedikit maka bisa dihapus

# %%
df.sort_values(by=['trip_time'],ascending = False).head(10)
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 8292          2  2023-01-18 06:58:14   2023-01-19 06:57:10         1.0
# 4595          2  2023-01-31 09:02:52   2023-02-01 09:01:47         1.0
# 14133         2  2023-01-27 08:56:22   2023-01-28 08:55:17         1.0
# 29133         2  2023-01-19 08:52:10   2023-01-20 08:51:03         3.0
# 25314         2  2023-01-16 20:09:38   2023-01-17 20:08:24         1.0
# 54779         2  2023-01-22 02:36:04   2023-01-23 02:34:42         1.0
# 10418         2  2023-01-19 16:18:58   2023-01-20 16:17:35         1.0
# 38734         2  2023-01-03 08:49:50   2023-01-04 08:47:12         1.0
# 13100         2  2023-01-22 13:16:38   2023-01-23 13:13:04         1.0
# 3764          2  2023-01-20 12:55:21   2023-01-21 12:51:19         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 8292             74            41              1.0           1.09
# 4595             41            42              1.0           0.87
# 14133            43           239              1.0           1.89
# 29133            75            75              1.0           0.04
# 25314            42            43              1.0           1.63
# 54779           129           129              1.0           0.42
# 10418           166           238              1.0           1.20
# 38734            74           141              1.0           3.22
# 13100            24           239              1.0           1.99
# 3764             75           229              1.0           2.99
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 8292           7.9    0.0      0.5        0.00           0.0
# 4595           7.9    0.0      0.5        0.00           0.0
# 14133         11.4    0.0      0.5        3.91           0.0
# 29133         23.0    0.0      0.0        7.20           0.0
# 25314         10.7    1.0      0.5        0.66           0.0
# 54779          5.8    1.0      0.5        0.00           0.0
# 10418          8.6    2.5      0.5        2.52           0.0
# 38734         19.1    0.0      0.5        0.00           0.0
# 13100         13.5    0.0      0.5        4.44           0.0
# 3764          20.5    0.0      0.5        2.40           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 8292                     1.0          9.40           1.0        1.0
# 4595                     1.0          9.40           1.0        1.0
# 14133                    1.0         15.65           1.0        1.0
# 29133                    1.0         24.00           1.0        1.0
# 25314                    1.0         13.20           1.0        1.0
# 54779                    1.0          8.30           2.0        1.0
# 10418                    1.0         12.60           1.0        1.0
# 38734                    1.0         23.35           1.0        1.0
# 13100                    1.0         17.75           1.0        1.0
# 3764                     0.3         24.05           1.0        1.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 8292                   0.00    86336.0  Wednesday     Morning      Manhattan
# 4595                   0.00    86335.0    Tuesday     Morning      Manhattan
# 14133                  2.75    86335.0     Friday     Morning      Manhattan
# 29133                  0.00    86333.0   Thursday     Morning      Manhattan
# 25314                  0.00    86326.0     Monday     Evening      Manhattan
# 54779                  0.00    86318.0     Sunday    Midnight         Queens
# 10418                  0.00    86317.0   Thursday   Afternoon      Manhattan
# 38734                  2.75    86242.0    Tuesday     Morning      Manhattan
# 13100                  2.75    86186.0     Sunday   Afternoon      Manhattan
# 3764                   2.75    86158.0     Friday   Afternoon      Manhattan
#
#                 pickup_zone dropoff_borough                   dropoff_zone
# 8292      East Harlem North       Manhattan                 Central Harlem
# 4595         Central Harlem       Manhattan           Central Harlem North
# 14133          Central Park       Manhattan          Upper West Side South
# 29133     East Harlem South       Manhattan              East Harlem South
# 25314  Central Harlem North       Manhattan                   Central Park
# 54779       Jackson Heights          Queens                Jackson Heights
# 10418   Morningside Heights       Manhattan          Upper West Side North
# 38734     East Harlem North       Manhattan                Lenox Hill West
# 13100          Bloomingdale       Manhattan          Upper West Side South
# 3764      East Harlem South       Manhattan  Sutton Place/Turtle Bay North

# %% [markdown]
# Untuk melihat anomali pada data trip_time ini saya menggunakan asumsi keliling sebesar 76.8 mil, dan kecepatan rata-rata di AS adalah 27 kph atau sekitar 17 mph.
#
# Maka dari itu saya mengasumsikan maksimal berkendara adalah 5 jam.
#
# Saya akan mencoba drop data yang memiliki waktu lebih dari 5 jam dan juga yang kurang dari 10 detik dikarenakan saya mengasumsikan apabila ada yang dibawah 10 detik tandanya terdapat kesalahan dalam pengambilan data ataupun tripnya canceled tapi tidak tercatat

# %%
df = df[(df['trip_time']<=18000) & (df['trip_time']>=10)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64050 entries, 0 to 68210
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64050 non-null  int64
#  1   lpep_pickup_datetime   64050 non-null  datetime64[s]
#  2   lpep_dropoff_datetime  64050 non-null  datetime64[s]
#  3   RatecodeID             64050 non-null  float64
#  4   PULocationID           64050 non-null  int64
#  5   DOLocationID           64050 non-null  int64
#  6   passenger_count        64050 non-null  float64
#  7   trip_distance          64050 non-null  float64
#  8   fare_amount            64050 non-null  float64
#  9   extra                  64050 non-null  float64
#  10  mta_tax                64050 non-null  float64
#  11  tip_amount             64050 non-null  float64
#  12  tolls_amount           64050 non-null  float64
#  13  improvement_surcharge  64050 non-null  float64
#  14  total_amount           64050 non-null  float64
#  15  payment_type           64050 non-null  float64
#  16  trip_type              64050 non-null  float64
#  17  congestion_surcharge   64050 non-null  float64
#  18  trip_time              64050 non-null  float64
#  19  day                    64050 non-null  object
#  20  time_of_day            64050 non-null  object
#  21  pickup_borough         64050 non-null  object
#  22  pickup_zone            64050 non-null  object
#  23  dropoff_borough        64050 non-null  object
#  24  dropoff_zone           64050 non-null  object
# dtypes: datetime64[s](2), float64(14), int64(3), object(6)
# memory usage: 12.7+ MB

# %%
# sorting berdasarkan tanggal dan jam
df = df.sort_values(by='lpep_pickup_datetime')
df.head()
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 445           2  2023-01-01 00:01:31   2023-01-01 00:16:02         1.0
# 39416         2  2023-01-01 00:04:25   2023-01-01 00:17:50         1.0
# 45441         2  2023-01-01 00:06:48   2023-01-01 01:08:47         1.0
# 28441         2  2023-01-01 00:08:05   2023-01-01 00:13:26         1.0
# 19514         2  2023-01-01 00:08:43   2023-01-01 00:17:08         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 445             166           244              1.0           2.48
# 39416           255           146              1.0           2.80
# 45441           129           226              2.0           7.83
# 28441            41            75              6.0           1.05
# 19514            75           140              1.0           1.99
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 445           16.3    1.0      0.5        3.76           0.0
# 39416         16.3    1.0      0.5        2.80           0.0
# 45441         52.0    1.0      0.5        0.00           0.0
# 28441          5.5    0.5      0.5        1.36           0.0
# 19514         11.4    1.0      0.5        3.33           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 445                      1.0         18.80           1.0        1.0
# 39416                    1.0         18.80           1.0        1.0
# 45441                    1.0         54.50           2.0        1.0
# 28441                    0.3          6.80           1.0        1.0
# 19514                    1.0         16.65           1.0        1.0
#
#        congestion_surcharge  trip_time     day time_of_day pickup_borough  \
# 445                    0.00      871.0  Sunday    Midnight      Manhattan
# 39416                  0.00      805.0  Sunday    Midnight       Brooklyn
# 45441                  0.00     3719.0  Sunday    Midnight         Queens
# 28441                  0.00      321.0  Sunday    Midnight      Manhattan
# 19514                  2.75      505.0  Sunday    Midnight      Manhattan
#
#                      pickup_zone dropoff_borough  \
# 445          Morningside Heights       Manhattan
# 39416  Williamsburg (North Side)          Queens
# 45441            Jackson Heights          Queens
# 28441             Central Harlem       Manhattan
# 19514          East Harlem South       Manhattan
#
#                         dropoff_zone
# 445         Washington Heights South
# 39416  Long Island City/Queens Plaza
# 45441                      Sunnyside
# 28441              East Harlem South
# 19514                Lenox Hill East

# %% [markdown]
# Selanjutnya, data yang sudah dibersihkan kita generate ke dalam bentuk CSV untuk dilakukan analisis selanjutnya

# %%
df.to_csv('NYC TLC Trip Record Clean.csv',index=False)

# %%
df.sort_values('trip_time')
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 56257         2  2023-01-07 13:13:45   2023-01-07 13:13:55         1.0
# 17554         2  2023-01-06 17:26:29   2023-01-06 17:26:39         1.0
# 17553         2  2023-01-06 17:26:29   2023-01-06 17:26:39         1.0
# 18190         2  2023-01-31 10:22:39   2023-01-31 10:22:49         1.0
# 17858         1  2023-01-19 09:35:28   2023-01-19 09:35:38         1.0
# ...         ...                  ...                   ...         ...
# 41291         2  2023-01-04 15:57:57   2023-01-04 18:35:30         1.0
# 57849         2  2023-01-03 13:05:16   2023-01-03 15:48:27         5.0
# 1769          2  2023-01-31 13:21:03   2023-01-31 16:13:32         1.0
# 57281         2  2023-01-09 14:05:14   2023-01-09 18:18:55         5.0
# 51629         2  2023-01-07 15:55:53   2023-01-07 20:38:53         1.0
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# 56257            95            95              1.0           0.01
# 17554            74            74              1.0           0.03
# 17553            74            74              1.0           0.03
# 18190            74            74              1.0           0.01
# 17858            74            74              1.0           1.40
# ...             ...           ...              ...            ...
# 41291            97           107              1.0          30.40
# 57849           134           134              1.0          22.62
# 1769            166           166              1.0          16.94
# 57281           134            95              1.0          28.67
# 51629           223           223              1.0          20.43
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 56257          3.0    0.0      0.5         0.0          0.00
# 17554          3.0    2.5      0.5         0.0          0.00
# 17553          3.0    2.5      0.5         0.0          0.00
# 18190          3.0    0.0      0.5         0.0          0.00
# 17858          1.5    0.0      1.5         0.0          0.00
# ...            ...    ...      ...         ...           ...
# 41291        154.9    0.0      0.5         0.0         13.10
# 57849         45.0    0.0      0.0         0.0          6.55
# 1769         145.1    0.0      0.5        10.0          0.00
# 57281         45.0    0.0      0.0         0.0          0.00
# 51629        230.5    0.0      0.5         0.0          0.00
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 56257                    1.0          4.50           2.0        1.0
# 17554                    1.0          7.00           3.0        1.0
# 17553                    1.0          7.00           3.0        1.0
# 18190                    1.0          4.50           2.0        1.0
# 17858                    1.0          4.00           1.0        1.0
# ...                      ...           ...           ...        ...
# 41291                    1.0        159.15           2.0        1.0
# 57849                    1.0         46.00           2.0        1.0
# 1769                     1.0        146.60           1.0        1.0
# 57281                    1.0         46.00           2.0        1.0
# 51629                    1.0        232.00           2.0        1.0
#
#        congestion_surcharge  trip_time        day time_of_day pickup_borough  \
# 56257                  0.00       10.0   Saturday   Afternoon         Queens
# 17554                  0.00       10.0     Friday   Afternoon      Manhattan
# 17553                  0.00       10.0     Friday   Afternoon      Manhattan
# 18190                  0.00       10.0    Tuesday     Morning      Manhattan
# 17858                  0.00       10.0   Thursday     Morning      Manhattan
# ...                     ...        ...        ...         ...            ...
# 41291                  2.75     9453.0  Wednesday   Afternoon       Brooklyn
# 57849                  0.00     9791.0    Tuesday   Afternoon         Queens
# 1769                   0.00    10349.0    Tuesday   Afternoon      Manhattan
# 57281                  0.00    15221.0     Monday   Afternoon         Queens
# 51629                  0.00    16980.0   Saturday   Afternoon         Queens
#
#                pickup_zone dropoff_borough         dropoff_zone
# 56257         Forest Hills          Queens         Forest Hills
# 17554    East Harlem North       Manhattan    East Harlem North
# 17553    East Harlem North       Manhattan    East Harlem North
# 18190    East Harlem North       Manhattan    East Harlem North
# 17858    East Harlem North       Manhattan    East Harlem North
# ...                    ...             ...                  ...
# 41291          Fort Greene       Manhattan             Gramercy
# 57849          Kew Gardens          Queens          Kew Gardens
# 1769   Morningside Heights       Manhattan  Morningside Heights
# 57281          Kew Gardens          Queens         Forest Hills
# 51629             Steinway          Queens             Steinway
#
# [64050 rows x 25 columns]
